# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
abund_mass= pd.read_csv(r"C:\Users\LENOVO\Documents\PostGrad\BSc Hons\4ZOL509_Research\data\abundance_biomass.csv")

# %%
# ------------------------
# 1. Abundance & Biomass per Site
# ------------------------
abundance_df = abund_mass.groupby('site')['prawn_id'].count().reset_index(name='abundance')
biomass_df = abund_mass.groupby('site')['dry_weight'].sum().reset_index(name='total_biomass')

fig, axes = plt.subplots(1, 2, figsize=(14, 6))  # side-by-side plots

# Abundance
sns.barplot(data=abundance_df, x='site', y='abundance', palette='Blues', ax=axes[0])
axes[0].set_title('Abundance of Sand Prawns by Site')
axes[0].set_xlabel('Site')
axes[0].set_ylabel('Number of Individuals')

# Biomass
sns.barplot(data=biomass_df, x='site', y='total_biomass', palette='Greens', ax=axes[1])
axes[1].set_title('Total Dry Biomass by Site')
axes[1].set_xlabel('Site')
axes[1].set_ylabel('Total Biomass (g)')

plt.tight_layout()
plt.savefig(r"C:\Users\LENOVO\Documents\PostGrad\BSc Hons\4ZOL509_Research\fig\abundance_biomass.png", dpi=300)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2308\2447046795.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=abundance_df, x='site', y='abundance', palette='Blues', ax=axes[0])
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2308\2447046795.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=biomass_df, x='site', y='total_biomass', palette='Greens', ax=axes[1])

# %%
# ------------------------
# 2. ABC Curves per Site & Replicate
# ------------------------
abund_mass_grouped = abund_mass.groupby(['site', 'replicate']).agg(
    abundance=('prawn_id', 'count'),
    biomass=('dry_weight', 'sum')
).reset_index()

sites = abund_mass_grouped['site'].unique()
n_sites = len(sites)

fig, axes = plt.subplots(n_sites, 1, figsize=(8, 15), sharex=True)

for i, site in enumerate(sites):
    ax = axes[i] if n_sites > 1 else axes
    subset = abund_mass_grouped[abund_mass_grouped['site'] == site].sort_values(by='replicate', ascending=False)
    
    # Cumulative percentages
    subset['cum_abundance'] = subset['abundance'].cumsum() / subset['abundance'].sum() * 100
    subset['cum_biomass'] = subset['biomass'].cumsum() / subset['biomass'].sum() * 100
    
    ax.plot(range(1, len(subset)+1), subset['cum_abundance'], marker='o', label='Cumulative Abundance')
    ax.plot(range(1, len(subset)+1), subset['cum_biomass'], marker='s', label='Cumulative Biomass')
    ax.set_title(f'ABC Curve – Site {site}')
    ax.set_ylabel('Cumulative Percentage (%)')
    ax.set_xticks(range(1, len(subset)+1))
    ax.grid(True)
    ax.legend()

axes[-1].set_xlabel('Replicate Sample Rank')
plt.tight_layout()
plt.savefig(r"C:\Users\LENOVO\Documents\PostGrad\BSc Hons\4ZOL509_Research\fig\abc_curve.png", dpi=300)
plt.show()

# %%
# ------------------------
# 3. Prawn Morphometrics & Reproductive Patterns
# ------------------------

# Ensure you have df defined as your abundance data
df = abund_mass.copy()

fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# Scatter: Carapace vs Total Length
sns.scatterplot(data=df, x='total_length', y='carapace', hue='site', palette='Set2', ax=axes[0,0])
axes[0,0].set_title('Carapace vs Total Length by Site')

# Boxplot: Total Length
sns.boxplot(data=df, x='site', y='total_length', palette='Set3', ax=axes[0,1])
axes[0,1].set_title('Total Length Across Sites')

# Scatter/Boxplot: Egg Count Distribution
sns.scatterplot(data=df, x='site', y='eggs', palette='Set1', ax=axes[1,0])
axes[1,0].set_title('Egg Count Distribution by Site')

# Correlation Heatmap
numeric_cols = df.select_dtypes(include='number').drop(columns=['replicate', 'sample'])
corr_matrix = numeric_cols.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', ax=axes[1,1])
axes[1,1].set_title('Correlation Matrix')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2308\2671781708.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='site', y='total_length', palette='Set3', ax=axes[0,1])
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2308\2671781708.py:19: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x='site', y='eggs', palette='Set1', ax=axes[1,0])
